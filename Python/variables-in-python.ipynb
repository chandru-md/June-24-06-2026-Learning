# %%
a = 100

# %%
b = 200

# %%
c = 300

# %%
print(a)
# Out:
# 100

# %%
print(b)
# Out:
# 200

# %%
print(c)
# Out:
# 300

# %%
first_name = "Chandru"

# %%
last_name = "Deivanayagan"

# %%
first_name
# Out:
# 'Chandru'

# %%
print(first_name)
# Out:
# Chandru

# %%
first_name+' '+last_name
# Out:
# 'Chandru Deivanayagan'

# %%
age = 24
height = 5.9
weight = 85
occupation = 'Unemployed'

# %%
print("Age:",age)
print("Height:",height)
print("Weight:",weight)
print("Occupation:",occupation)
# Out:
# Age: 24
# Height: 5.9
# Weight: 85
# Occupation: Unemployed

# %%
## Naming conventions

# variable names should be descriptive
# they starts with a number, letter and underscores
# variable name are case-sensitive

# %%
first_name = "Chandru"

# %%
_first_name_ = "Kathiravan"

# %%
2age = 50
# Out:
#   Cell In[18], line 1
#     2age = 50
#     ^
# SyntaxError: invalid decimal literal

# %%
last-name = "M D"
# Out:
#   Cell In[19], line 1
#     last-name = "M D"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
@full_name = "M D Chandru"
# Out:
#   Cell In[20], line 1
#     @full_name = "M D Chandru"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
name = "Sweety"

# %%
Name = "Omana"

# %%
name
# Out:
# 'Sweety'

# %%
Name
# Out:
# 'Omana'

# %%
# variable types

# %%
#Python is dynammically typed. type of a variable is determined.

# %%
age = 25 #integer
height = 5.56 # float
name = "Chandru"
is_student = True  # Boolean

# %%
age
# Out:
# 25

# %%
height
# Out:
# 5.56

# %%
name
# Out:
# 'Chandru'

# %%
is_student
# Out:
# True

# %%
# Type-checking and conversion

# %%
type(age)
# Out:
# int

# %%
type(height)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(is_student)
# Out:
# bool

# %%
# Type conversion


age_str = str(age)
print(age)
print(type(age))
print(age_str)
print(type(age_str))
# Out:
# 25
# <class 'int'>
# 25
# <class 'str'>

# %%
name ="Chandru"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 name ="Chandru"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Chandru'

# %%
height = 6.66
print(type(height))
print(int(height))
# Out:
# <class 'float'>
# 6

# %%
print(float(age))
# Out:
# 25.0

# %%
chandru = 85

print(chandru, type(chandru))

chandru = "Sweety"

print(chandru,type(chandru))

chandru = 3.14

print(chandru,type(chandru))
# Out:
# 85 <class 'int'>
# Sweety <class 'str'>
# 3.14 <class 'float'>

# %%
age = input("Enter your age: ")
print(age)
# Out:
# 25

# %%
type(age)
# Out:
# str

# %%
age = int(input("Enter your age: "))
print(age,type(age))
# Out:
# 22 <class 'int'>

# %%
# Simple Calculator

# %%
num_1 = int(input("Enter your num1: "))
num_2 = int(input("Enter your num2: "))

add = num_1+num_2
sub = num_1-num_2
div = num_1/num_2
mult = num_1*num_2

print("Addition: ",add)
print("Substraction: ",sub)
print("Division: ",div)
print("Multiplication: ",mult)
# Out:
# Addition:  102
# Substraction:  -54
# Division:  0.3076923076923077
# Multiplication:  1872
