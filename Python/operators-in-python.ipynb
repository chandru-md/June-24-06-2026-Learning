# %%
# Arthmetic Operations

# %%
a = 10

b = 15

result = a + b

print(result)
# Out:
# 25

# %%
add_result = a+b
sub_result  = a-b
mult_result = a*b
div_result = a/b
floor_result = a//b
modulus_result = a%b
exponential_result = a**b


print(add_result)

print(sub_result)

print(mult_result)

print(div_result)

print(floor_result)

print(modulus_result)

print(exponential_result)
# Out:
# 25
# -5
# 150
# 0.6666666666666666
# 0
# 10
# 1000000000000000

# %%
21/4
# Out:
# 5.25

# %%
21//4
# Out:
# 5

# %%
21%4
# Out:
# 1

# %%
## Comparison Operators

# Equal to -- ==

# %%
10 == 10
# Out:
# True

# %%
a = 10

b= 10

a == b

print(a==b)
# Out:
# True

# %%
str1 = "Chandru"

str2 = "Chandru"


str1 == str2
# Out:
# True

# %%
str1 = "Chandru"

str2 = "chandru"


str1 == str2
# Out:
# False

# %%
## Not equal to !=

# %%
str1 = "Chandru"

str2 = "chandru"


str1 != str2
# Out:
# True

# %%
str1 = "Chandru"

str2 = "Chandru"


str1 != str2
# Out:
# False

# %%
# greater than >

num1 = 78
num2 = 90

print(num1> num2)
# Out:
# False

# %%
# lesser than <

num1 = 78
num2 = 90

print(num1 < num2)
# Out:
# True

# %%
# greater than or equal to >=

# %%
num1  = 45
num2 = 45

print(num1>=num2)
# Out:
# True

# %%
# less than or  equal to <=

num1  = 45
num2 = 45

print(num1 <= num2)
# Out:
# True

# %%
## Logical Operators

## AND -- NOT -- OR

x = True
y = True

print(x and y)
# Out:
# True

# %%
# and

x = True
y = False
print(x and y)
# Out:
# False

# %%
# OR

x = True
y = False
print(x or y)
# Out:
# True

# %%
# NOT

# reverse of the boolean variable
x = True

not x
# Out:
# False

# %%
# SImple Calculator


num_1 = int(input("Enter your num1: "))
num_2 = int(input("Enter your num2: "))

add = num_1+num_2
sub = num_1-num_2
div = num_1/num_2
mult = num_1*num_2
mod = num_1%num_2
exp = num_1**num_2
floor_div = num_1//num_2

print("Addition: ",add)
print("Substraction: ",sub)
print("Division: ",div)
print("Multiplication: ",mult)

print("Modulus: ",mod)
print("exp: ",exp)
print("floor_div: ",floor_div)
# Out:
# Addition:  37
# Substraction:  11
# Division:  1.8461538461538463
# Multiplication:  312
# Modulus:  11
# exp:  876488338465357824
# floor_div:  1
