# %%
my_dogs = 2

# %%
print(my_dogs)
# Out:
# 2

# %%
my_dogs = ["Sweety","Devi"]

# %%
my_dogs
# Out:
# ['Sweety', 'Devi']

# %%
type(my_dogs)
# Out:
# list

# %%
type(my_dogs)
# Out:
# int

# %%
a  =109
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.45

print(type(b))
# Out:
# <class 'float'>

# %%
c = "Kathiravan"
print(type(c))
# Out:
# <class 'str'>

# %%
d = "False"
print(type(d))
# Out:
# <class 'str'>

# %%
my_income = 100

tax_rate = 0.1

my_tax = my_income * tax_rate

# %%
print(my_tax)
# Out:
# 10.0
