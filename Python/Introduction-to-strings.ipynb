# %%
## STRINGS

"HELLO"
# Out:
# 'HELLO'

# %%
'CHANDRU'
# Out:
# 'CHANDRU'

# %%
'kathiravan'
# Out:
# 'kathiravan'

# %%
'''DEIVANAYAGAN'''
# Out:
# 'DEIVANAYAGAN'

# %%
print("Hello's world")
# Out:
# Hello's world

# %%
print("Chandru\nDeivanayagan")
# Out:
# Chandru
# Deivanayagan

# %%
len("Chandru")
# Out:
# 7

# %%
## SLICING  AND INDEXING

# %%
len("Hello world")
# Out:
# 11

# %%
my_str = "Hello World"

# %%
my_str
# Out:
# 'Hello World'

# %%
my_str[0]
# Out:
# 'H'

# %%
my_str[-3]
# Out:
# 'r'

# %%
my_str[8]
# Out:
# 'r'

# %%
my_str[9]
# Out:
# 'l'

# %%
my_str[-2]
# Out:
# 'l'

# %%
my_str
# Out:
# 'Hello World'

# %%
my_str = "abcdefghijklmnopqrstuvwxyz"

# %%
my_str[2:]
# Out:
# 'cdefghijklmnopqrstuvwxyz'

# %%
my_str[:-2]
# Out:
# 'abcdefghijklmnopqrstuvwx'

# %%
my_str[:3]
# Out:
# 'abc'

# %%
my_str[3:6]
# Out:
# 'def'

# %%
my_str
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
my_str[1:4]
# Out:
# 'bcd'

# %%
my_str
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
my_str[::2]
# Out:
# 'acegikmoqsuwy'

# %%
my_str[::3]
# Out:
# 'adgjmpsvy'

# %%
my_str[2:7:2]
# Out:
# 'ceg'

# %%
my_str[::-1]
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %%
## PROPERITIES AND METHODS

# %%
name = "Sammy"

last_letters = name[1:]
print(last_letters)
# Out:
# ammy

# %%
name[0] = 'P'  # Immutability
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 name[0] = 'P'  # Immutability
#
# TypeError: 'str' object does not support item assignment

# %%
"P" + last_letters
# Out:
# 'Pammy'

# %%
x = "Hello world"

# %%
x = x + " It's beautiful outside."

# %%
x
# Out:
# "Hello world It's beautiful outside."

# %%
letter = "z"

# %%
letter * 20
# Out:
# 'zzzzzzzzzzzzzzzzzzzz'

# %%
20 + 40
# Out:
# 60

# %%
"20" + "50"
# Out:
# '2050'

# %%
name = "Sweety Omana"

# %%
name.upper()
# Out:
# 'SWEETY OMANA'

# %%
name.lower()
# Out:
# 'sweety omana'

# %%
name.startswith("Sw")
# Out:
# True

# %%
name.endswith("ty")
# Out:
# False

# %%
name.split()
# Out:
# ['Sweety', 'Omana']

# %%
name.split('O')
# Out:
# ['Sweety ', 'mana']

# %%
# FORMATTING

# %%
print("This is the string {}".format("Added"))
# Out:
# This is the string Added

# %%
print("{} {} {}".format("CHandru","Sweety","DEvi"))
# Out:
# CHandru Sweety DEvi

# %%
print("the {s} {d} {c}".format(c = "CHandru",s = "Sweety",d = "DEvi"))
# Out:
# the Sweety DEvi CHandru

# %%
 # # float formatting

# %%
result = 100/777

# %%
print(result)
# Out:
# 0.1287001287001287

# %%
print("the result was {r:1.3f}".format(r = result))
# Out:
# the result was 0.129

# %%
print("the result was {r:1.3f}".format(r = result))
# Out:
# the result was 0.129

# %%
print("the result was {r:10.3f}".format(r = result))
# Out:
# the result was      0.129

# %%
# f-strings

# %%
name = "Chandru"

# %%
print(f"My name is {name}")
# Out:
# My name is Chandru

# %%
a_name = "Sweety"
age = 25
print(f"My name is {a_name} and I am {age} year's old")
# Out:
# My name is Sweety and I am 25 year's old
