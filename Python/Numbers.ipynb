# %%
2+2
# Out:
# 4

# %%
2-9
# Out:
# -7

# %%
4/2
# Out:
# 2.0

# %%
2*78
# Out:
# 156

# %%
# MOdular or Mod

# %%
43 % 2
# Out:
# 1

# %%
50 % 5
# Out:
# 0

# %%
45/ 4
# Out:
# 11.25

# %%
34//4
# Out:
# 8

# %%
2**8
# Out:
# 256

# %%
343 // 7
# Out:
# 49
