# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Data Types

# %%
# int
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
# float
b = 32.22
print(type(b))
# Out:
# <class 'float'>

# %%
#Bool
c = True
print(type(c))
# Out:
# <class 'bool'>

# %%
# string
d = "Chandru"
print(type(d))
# Out:
# <class 'str'>

# %%
# list
z = [1,2,3,4,5]
print(type(z))
# Out:
# <class 'list'>

# %%
# tuple
y = (1,2,3,4,5)
print(type(y))
# Out:
# <class 'tuple'>

# %%
# set
x = {1,2,3,4,4,5,5,5,5}
print(type(x))
# Out:
# <class 'set'>

# %%
# dictionary
v = {"name":"Chandru","Location":"India"}
print(type(v))
# Out:
# <class 'dict'>
